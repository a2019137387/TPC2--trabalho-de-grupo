# %% [markdown]
# **Url para o conjunto de dados :**
# http://geodados.cm-lisboa.pt/datasets/monumentos-nacionais

# %% [markdown]
# **Fundamentação da escolha de dados:**
# Decidimos utilizar este conjunto de dados relativamente ao património nacional na cidade de Lisboa, primeiramente porque
# a cultura tem de ser mais valorizada no nosso país, principalmente nesta altura em que estamos em casa e são os conteúdos culturais
# que nos distraem. Seguidamente porque é importante nesta altura valorizar o turismo interno do nosso país, para restabelecer
# a economia e para isso nada melhor que estar a par daquilo que podemos visitar.

# %% [markdown]
# **Escrevam o código que carrega o conjunto de dados usando a função read_csv,
# e mostrem as 10 primeiras linhas do conjunto de dados.**

# %%
import pandas as pd

df_data = pd.read_csv('Patrimonio.csv')
df_data.head(10)
# Out:
#    OBJECTID        COD_SIG  IDTIPO  \
# 0         1  3100411001001       2
# 1         2  2301701019001       2
# 2         3  4601204017001       2
# 3         4  4601204017001       2
# 4         5  3800805001001       2
# 5         6  5200305001001       2
# 6         7  5200304001001       2
# 7         8  2700301048001       2
# 8         9  3202701025001       2
# 9        10  2106718019001       2
#
#                                             INF_NOME  \
# 0                        Teatro Nacional D. Maria II
# 1  Edifício-Sede e Parque da Fundação Calouste Gu...
# 2           Reservatório da Mãe d'Água das Amoreiras
# 3  Aqueduto das Águas Livres, seus aferentes e co...
# 4             Paços de São Cristóvão (Porta lateral)
# 5         Sé de Lisboa (Igreja de Santa Maria Maior)
# 6                  Igreja de Santo António de Lisboa
# 7                        Igreja do Convento do Carmo
# 8    Palácio Nacional de Belém (conjunto intramuros)
# ...

# %% [markdown]
# **Qual é o tipo de dados de cada atributo?**

# %%
df_data.dtypes
# Out:
# OBJECTID           int64
# COD_SIG            int64
# IDTIPO             int64
# INF_NOME          object
# INF_MORADA        object
# INF_TELEFONE      object
# INF_FAX          float64
# INF_EMAIL         object
# INF_SITE          object
# INF_DESCRICAO     object
# INF_FONTE         object
# INF_MUNICIPAL      int64
# GlobalID          object
# dtype: object

# %% [markdown]
# **Ver o primeiro monumento**

# %% [markdown]
# ![405_17704860915ec2afa9e7364.png](attachment:405_17704860915ec2afa9e7364.png)

# %% [markdown]
# **Ver o segundo monumento**

# %% [markdown]
# ![Fundacao_Calouste_Gulbenkian_Lisboa.jpg](attachment:Fundacao_Calouste_Gulbenkian_Lisboa.jpg)
