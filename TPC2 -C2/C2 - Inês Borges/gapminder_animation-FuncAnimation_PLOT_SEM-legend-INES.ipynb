# %%
# libraries
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96

# %%
# Get the data (csv file is hosted on the web)
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)
#data=pd.read_csv('gapminderData.csv')
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...
data['continent']=pd.Categorical(data['continent'])

# %%
anos=data.year.unique()

# %%
# %matplotlib notebook
# %matplotlib notebook

import matplotlib.patches as mpatches

# initialize a figure
#fig=plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
fig, ax = plt.subplots(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)

# Add titles (main and on axis)
plt.yscale('log')
plt.xlabel("Life Expectancy")
plt.ylabel("GDP per Capita")
plt.ylim(100,100000)
plt.xlim(30, 90)

def animate(i):
    plt.title("Year: "+str(anos[i]) )
    tmp=data[ data.year == anos[i] ]
    scut=plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
    
ani = animation.FuncAnimation(fig, animate, frames=len(anos), interval=200, blit=False, repeat=False)
    

f = open('gapminderData.csv')
gapminderDataDF = pd.read_csv(f)


plt.plot([1, 2, 3], label="Asia", marker='o', color="w", markerfacecolor='lightgreen', markersize=10)
plt.plot([3, 2, 1], label="Europa", marker='o', color='w', markerfacecolor='moccasin', markersize=10)
plt.plot([3, 2, 1], label="Africa", marker='o', color='w', markerfacecolor='royalblue', markersize=10)
plt.plot([3, 2, 1], label="Oceania", marker='o', color='w', markerfacecolor='grey', markersize=10)
plt.plot([3, 2, 1], label="Americas", marker='o', color='w', markerfacecolor='chocolate', markersize=10)
plt.legend(bbox_to_anchor=(0.79, 0.25, 0.3, 0.1), loc='upper left', title="Continents")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="680">
